# %%
# Título: ImportAI - Optimización de Importación y Venta con IA
# Autor: Santiago González
# Curso: Inteligencia Artificial - Generación de Prompts
# Comisión: 84165

# Instalación de la biblioteca de Google Generative AI
# !pip install -q google-generativeai

import google.generativeai as genai
import time

# Configuración de la API de Google Gemini con tu nueva clave
api_key = "AIzaSyBRYO6V85ESKBcJA2f7HB3zbWK0_cfkOz4"
genai.configure(api_key=api_key)

# Configuración del modelo Gemini
model = genai.GenerativeModel("gemini-1.5-flash")  # Modelo gratuito y rápido

# Función para llamar a Gemini con Fast Prompting
def call_gemini(prompt):
    try:
        response = model.generate_content(
            f"System: You are a helpful assistant for product import optimization.\nUser: {prompt}",
            generation_config={
                "max_output_tokens": 150,  # Limitamos tokens para optimizar
                "temperature": 0.7
            }
        )
        return response.text.strip()
    except Exception as e:
        return f"Error: {str(e)} - Verifica la API key y el proyecto en https://console.cloud.google.com/"

# Introducción al proyecto
print("=== ImportAI: Optimización de Importación y Venta con IA ===")
print("Este proyecto usa Fast Prompting con Google Gemini para optimizar la importación y venta de productos en Uruguay.")
print("Objetivos: Seleccionar categorías rentables, estimar márgenes, sugerir proveedores y optimizar presentaciones visuales.")
print()

# Prompt 1: Categorías de productos
prompt_categorias = "Dame una lista corta de 3 categorías de productos con alta demanda y baja competencia en Uruguay, basándote en tendencias generales."
print("Prompt 1: Categorías de productos")
print(call_gemini(prompt_categorias))
print()

# Prompt 2: Estimación de rentabilidad
prompt_rentabilidad = "Estima el margen de rentabilidad potencial para estas categorías en Uruguay: Ropa deportiva, Accesorios electrónicos, Juguetes educativos."
print("Prompt 2: Rentabilidad")
print(call_gemini(prompt_rentabilidad))
print()

# Prompt 3: Proveedores confiables (con Accesorios electrónicos)
prompt_proveedores = "Sugiere proveedores confiables en Temu o Amazon para accesorios electrónicos y juguetes educativos, considerando calidad y presentación."
print("Prompt 3: Proveedores")
print(call_gemini(prompt_proveedores))
print()

# Prompt 4: Descripción de imágenes optimizadas (con Accesorios electrónicos)
prompt_imagen = "Describe una imagen optimizada para vender accesorios electrónicos en Uruguay: usa colores vibrantes y un fondo atractivo para captar atención."
print("Prompt 4: Descripción de imagen (generada en Nightcafe)")
imagen_desc = call_gemini(prompt_imagen)
print(imagen_desc)
print()
print("Enlace a la imagen generada en Nightcafe:")
print("https://creator.nightcafe.studio/studio?open=creation&panelContext=%28jobId%3ADy7na3ujD9zx7SDiWA5T%29")

# Fin
print("=== Fin de la demostración ===")
print("Proyecto optimizado con Fast Prompting: prompts directos y respuestas limitadas a 150 tokens.")
# Out:
# === ImportAI: Optimización de Importación y Venta con IA ===
# Este proyecto usa Fast Prompting con Google Gemini para optimizar la importación y venta de productos en Uruguay.
# Objetivos: Seleccionar categorías rentables, estimar márgenes, sugerir proveedores y optimizar presentaciones visuales.
#
# Prompt 1: Categorías de productos
# Basándome en tendencias generales y sin datos de mercado específicos de Uruguay (que requerirían investigación más profunda), tres categorías de productos con potencial de alta demanda y baja competencia *podrían* ser:
#
# ...
